# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "/content/pima-indians-diabetes.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    No of times pregnant  Plasma glucose concentration  \
# 0                     6                           148
# 1                     1                            85
# 2                     8                           183
# 3                     1                            89
# 4                     0                           137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  Body mass index  Diabets pedigree function  \
# 0                               0             33.6                      0.627
# 1                               0             26.6                      0.351
# 2                               0             23.3                      0.672
# 3                              94             28.1                      0.167
# 4                             168             43.1                      2.288
#
#    Age  Class variable
# 0   50               1
# 1   31               0
# 2   32               1
# 3   21               0
# 4   33               1

# %%
df.tail()
# Out:
#      No of times pregnant  Plasma glucose concentration  \
# 763                    10                           101
# 764                     2                           122
# 765                     5                           121
# 766                     1                           126
# 767                     1                            93
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 763                                76                                48
# 764                                70                                27
# 765                                72                                23
# 766                                60                                 0
# 767                                70                                31
#
#      2-Hour serum insulin (mu U/ml)  Body mass index  \
# 763                             180             32.9
# 764                               0             36.8
# 765                             112             26.2
# 766                               0             30.1
# 767                               0             30.4
#
#      Diabets pedigree function  Age  Class variable
# 763                      0.171   63               0
# 764                      0.340   27               0
# 765                      0.245   30               0
# 766                      0.349   47               1
# 767                      0.315   23               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   No of times pregnant              768 non-null    int64
#  1   Plasma glucose concentration      768 non-null    int64
#  2   Diastolic blood pressure (mm Hg)  768 non-null    int64
#  3   Triceps skin fold thickness (mm)  768 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)    768 non-null    int64
#  5   Body mass index                   768 non-null    float64
#  6   Diabets pedigree function         768 non-null    float64
#  7   Age                               768 non-null    int64
#  8   Class variable                    768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        No of times pregnant  Plasma glucose concentration  \
# count            768.000000                    768.000000
# mean               3.845052                    120.894531
# std                3.369578                     31.972618
# min                0.000000                      0.000000
# 25%                1.000000                     99.000000
# 50%                3.000000                    117.000000
# 75%                6.000000                    140.250000
# max               17.000000                    199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         20.536458
# std                           19.355807                         15.952218
# min                            0.000000                          0.000000
# 25%                           62.000000                          0.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  Body mass index  \
# count                      768.000000       768.000000
# mean                        79.799479        31.992578
# std                        115.244002         7.884160
# min                          0.000000         0.000000
# 25%                          0.000000        27.300000
# 50%                         30.500000        32.000000
# 75%                        127.250000        36.600000
# max                        846.000000        67.100000
#
#        Diabets pedigree function         Age  Class variable
# count                 768.000000  768.000000      768.000000
# mean                    0.471876   33.240885        0.348958
# std                     0.331329   11.760232        0.476951
# min                     0.078000   21.000000        0.000000
# 25%                     0.243750   24.000000        0.000000
# 50%                     0.372500   29.000000        0.000000
# 75%                     0.626250   41.000000        1.000000
# max                     2.420000   81.000000        1.000000

# %%
df.shape
# Out:
# (768, 9)

# %%
df['Class variable'].value_counts()
# Out:
# Class variable
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
sns.countplot(x='Class variable', data=df)
plt.show()

# %%
(df[['No of times pregnant','Plasma glucose concentration','Diastolic blood pressure (mm Hg)','Triceps skin fold thickness (mm)','2-Hour serum insulin (mu U/ml)','Body mass index']] == 0).sum()
# Out:
# No of times pregnant                111
# Plasma glucose concentration          5
# Diastolic blood pressure (mm Hg)     35
# Triceps skin fold thickness (mm)    227
# 2-Hour serum insulin (mu U/ml)      374
# Body mass index                      11
# dtype: int64
